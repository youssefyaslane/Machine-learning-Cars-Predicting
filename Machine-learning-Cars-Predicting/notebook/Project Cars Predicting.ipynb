# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r'C:\Users\user\Desktop\Project_cars\data\car_price_prediction.csv')

# %%
display(data)
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     -          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
# ...

# %%
data.head(10)
# Out:
#          ID  Price  Levy Manufacturer     Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS    RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET   Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA       FIT        2006  Hatchback
# 3  45769185   3607   862         FORD    Escape        2011       Jeep
# 4  45809263  11726   446        HONDA       FIT        2014  Hatchback
# 5  45802912  39493   891      HYUNDAI  Santa FE        2016       Jeep
# 6  45656768   1803   761       TOYOTA     Prius        2010  Hatchback
# 7  45816158    549   751      HYUNDAI    Sonata        2013      Sedan
# 8  45641395   1098   394       TOYOTA     Camry        2014      Sedan
# 9  45756839  26657     -        LEXUS    RX 350        2007       Jeep
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# ...

# %%
data.shape
# Out:
# (19237, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19237 non-null  int64
#  1   Price             19237 non-null  int64
#  2   Levy              19237 non-null  object
#  3   Manufacturer      19237 non-null  object
#  4   Model             19237 non-null  object
#  5   Prod. year        19237 non-null  int64
#  6   Category          19237 non-null  object
#  7   Leather interior  19237 non-null  object
#  8   Fuel type         19237 non-null  object
#  9   Engine volume     19237 non-null  object
#  10  Mileage           19237 non-null  object
#  11  Cylinders         19237 non-null  float64
#  12  Gear box type     19237 non-null  object
#  13  Drive wheels      19237 non-null  object
#  14  Doors             19237 non-null  object
#  15  Wheel             19237 non-null  object
# ...

# %%
data.describe()
# Out:
#                  ID         Price    Prod. year     Cylinders       Airbags
# count  1.923700e+04  1.923700e+04  19237.000000  19237.000000  19237.000000
# mean   4.557654e+07  1.855593e+04   2010.912824      4.582991      6.582627
# std    9.365914e+05  1.905813e+05      5.668673      1.199933      4.320168
# min    2.074688e+07  1.000000e+00   1939.000000      1.000000      0.000000
# 25%    4.569837e+07  5.331000e+03   2009.000000      4.000000      4.000000
# 50%    4.577231e+07  1.317200e+04   2012.000000      4.000000      6.000000
# 75%    4.580204e+07  2.207500e+04   2015.000000      4.000000     12.000000
# max    4.581665e+07  2.630750e+07   2020.000000     16.000000     16.000000

# %%
# nombre de repetition 
data.duplicated().sum()
# Out:
# 313

# %%
# effacer data rep 
data.drop_duplicates(inplace=True)
data.duplicated().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (18924, 18)

# %%
data.isnull().sum()
# Out:
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64

# %% [markdown]
# # analyse de data

# %%
 data['Manufacturer'].unique()
# Out:
# array(['LEXUS', 'CHEVROLET', 'HONDA', 'FORD', 'HYUNDAI', 'TOYOTA',
#        'MERCEDES-BENZ', 'OPEL', 'PORSCHE', 'BMW', 'JEEP', 'VOLKSWAGEN',
#        'AUDI', 'RENAULT', 'NISSAN', 'SUBARU', 'DAEWOO', 'KIA',
#        'MITSUBISHI', 'SSANGYONG', 'MAZDA', 'GMC', 'FIAT', 'INFINITI',
#        'ALFA ROMEO', 'SUZUKI', 'ACURA', 'LINCOLN', 'VAZ', 'GAZ',
#        'CITROEN', 'LAND ROVER', 'MINI', 'DODGE', 'CHRYSLER', 'JAGUAR',
#        'ISUZU', 'SKODA', 'DAIHATSU', 'BUICK', 'TESLA', 'CADILLAC',
#        'PEUGEOT', 'BENTLEY', 'VOLVO', 'სხვა', 'HAVAL', 'HUMMER', 'SCION',
#        'UAZ', 'MERCURY', 'ZAZ', 'ROVER', 'SEAT', 'LANCIA', 'MOSKVICH',
#        'MASERATI', 'FERRARI', 'SAAB', 'LAMBORGHINI', 'ROLLS-ROYCE',
#        'PONTIAC', 'SATURN', 'ASTON MARTIN', 'GREATWALL'], dtype=object)

# %%
for col in data.columns : 
    print(col,":",data[col].nunique())
# Out:
# ID : 18924
# Price : 2315
# Levy : 559
# Manufacturer : 65
# Model : 1590
# Prod. year : 54
# Category : 11
# Leather interior : 2
# Fuel type : 7
# Engine volume : 107
# Mileage : 7687
# Cylinders : 13
# Gear box type : 4
# Drive wheels : 3
# Doors : 3
# Wheel : 2
# Color : 16
# Airbags : 17

# %%
data.hist(bins=15,figsize=(15,10))
plt.show()

# %%
top10Cars=data['Manufacturer'].value_counts()[:10]

# %%
top10Cars.plot(figsize=(10,3))
plt.show()

# %%
for i in list(top10Cars.index):
 p=data[data['Manufacturer']==i]['Price'].mean()
 print(p)
# Out:
# 22306.00080450523
# 14302.447864669994
# 18590.331375428294
# 15411.85018382353
# 14894.873925501433
# 20609.468146718147
# 14162.073958333332
# 20052.594390507013
# 9835.84031007752
# 11471.77408056042

# %%
#autre methode  

top10meanPrices = [data[data['Manufacturer']==i]['Price'].mean() for i in list(top10Cars.index)]



top10meanPrices
# Out:
# [22306.00080450523,
#  14302.447864669994,
#  18590.331375428294,
#  15411.85018382353,
#  14894.873925501433,
#  20609.468146718147,
#  14162.073958333332,
#  20052.594390507013,
#  9835.84031007752,
#  11471.77408056042]

# %%
plt.plot(top10Cars.index,top10meanPrices)
plt.show()

# %%
#collect 

cor=data.corr()

# %%
sns.heatmap(cor,linewidth='0.5',annot=True,fmt='.3f')
# Out:
# <Axes: >

# %%
data_object=data.select_dtypes(include='object')

# %%
for col in data_object :
    plt.figure(figsize=(15,5))
    top10=data[col].value_counts()[:10]
    top10.plot(kind='bar')
    plt.title('Top10'+" "+col)
    plt.show()

# %% [markdown]
# # Pre Data

# %%
data=data.drop(['ID'],axis=1)

# %%
data['Doors'].replace({'04-May':4, '02-Mar':2, '>5':5}, inplace=True)

# %%
data.head()
# Out:
#    Price  Levy Manufacturer    Model  Prod. year   Category Leather interior  \
# 0  13328  1399        LEXUS   RX 450        2010       Jeep              Yes
# 1  16621  1018    CHEVROLET  Equinox        2011       Jeep               No
# 2   8467     -        HONDA      FIT        2006  Hatchback               No
# 3   3607   862         FORD   Escape        2011       Jeep              Yes
# 4  11726   446        HONDA      FIT        2014  Hatchback              Yes
#
#   Fuel type Engine volume    Mileage  Cylinders Gear box type Drive wheels  \
# 0    Hybrid           3.5  186005 km        6.0     Automatic          4x4
# 1    Petrol             3  192000 km        6.0     Tiptronic          4x4
# 2    Petrol           1.3  200000 km        4.0      Variator        Front
# 3    Hybrid           2.5  168966 km        4.0     Automatic          4x4
# 4    Petrol           1.3   91901 km        4.0     Automatic        Front
#
#    Doors             Wheel   Color  Airbags
# ...

# %%
#date
import datetime
dtime=datetime.datetime.now()

# %%
data['Age']=dtime.year-data['Prod. year']

# %%
data.head(10)
# Out:
#    Price  Levy Manufacturer     Model  Prod. year   Category Leather interior  \
# 0  13328  1399        LEXUS    RX 450        2010       Jeep              Yes
# 1  16621  1018    CHEVROLET   Equinox        2011       Jeep               No
# 2   8467     -        HONDA       FIT        2006  Hatchback               No
# 3   3607   862         FORD    Escape        2011       Jeep              Yes
# 4  11726   446        HONDA       FIT        2014  Hatchback              Yes
# 5  39493   891      HYUNDAI  Santa FE        2016       Jeep              Yes
# 6   1803   761       TOYOTA     Prius        2010  Hatchback              Yes
# 7    549   751      HYUNDAI    Sonata        2013      Sedan              Yes
# 8   1098   394       TOYOTA     Camry        2014      Sedan              Yes
# 9  26657     -        LEXUS    RX 350        2007       Jeep              Yes
#
#   Fuel type Engine volume    Mileage  Cylinders Gear box type Drive wheels  \
# ...

# %%
data= data.drop(['Prod. year'],axis=1)
data= data.drop(['Color'],axis=1)
data= data.drop(['Wheel'],axis=1)

# %% [markdown]
# # levy

# %%
data.Levy.replace({'-': '0'},inplace=True)
data['Levy'] = data['Levy'].astype(int)

# %% [markdown]
# # millage

# %%
data['Mileage']=data['Mileage'].str.replace('km', '')

# %% [markdown]
# # Engine volume

# %%
data['Engine volume']=data['Engine volume'].str.replace('Turbo','')
data['Engine volume']=data['Engine volume'].astype(float)

# %% [markdown]
# # outlier

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18924 entries, 0 to 19236
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price             18924 non-null  int64
#  1   Levy              18924 non-null  int32
#  2   Manufacturer      18924 non-null  object
#  3   Model             18924 non-null  object
#  4   Category          18924 non-null  object
#  5   Leather interior  18924 non-null  object
#  6   Fuel type         18924 non-null  object
#  7   Engine volume     18924 non-null  float64
#  8   Mileage           18924 non-null  object
#  9   Cylinders         18924 non-null  float64
#  10  Gear box type     18924 non-null  object
#  11  Drive wheels      18924 non-null  object
#  12  Doors             18924 non-null  int64
#  13  Airbags           18924 non-null  int64
#  14  Age               18924 non-null  int64
# dtypes: float64(2), int32(1), int64(4), object(8)
# ...

# %%
data_numeric = data.select_dtypes(exclude='object')

for col in data_numeric: 
    q1=data[col].quantile(0.25)
    q3=data[col].quantile(0.75)
    iqr = q3-q1
    low=q1-1.5*iqr
    high=q3+1.5*iqr
    outlier = ((data_numeric[col]>high)|(data_numeric[col]<low)).sum()
    total=data_numeric[col].shape[0]
    print(f"totale outliers in {col} are : {outlier}--{round(100*(outlier)/total,2)}%")
    if outlier>0 :
        data=data.loc[(data[col]<=high) & (data[col]>=low)]
# Out:
# totale outliers in Price are : 1055--5.57%
# totale outliers in Levy are : 172--0.91%
# totale outliers in Engine volume are : 1358--7.18%
# totale outliers in Cylinders are : 4765--25.18%
# totale outliers in Doors are : 892--4.71%
# totale outliers in Airbags are : 0--0.0%
# totale outliers in Age are : 1777--9.39%

# %%
display(data)
# Out:
#        Price  Levy Manufacturer     Model   Category Leather interior  \
# 2       8467     0        HONDA       FIT  Hatchback               No
# 3       3607   862         FORD    Escape       Jeep              Yes
# 4      11726   446        HONDA       FIT  Hatchback              Yes
# 5      39493   891      HYUNDAI  Santa FE       Jeep              Yes
# 6       1803   761       TOYOTA     Prius  Hatchback              Yes
# ...      ...   ...          ...       ...        ...              ...
# 19230    470   645       TOYOTA     Prius  Hatchback              Yes
# 19233  15681   831      HYUNDAI    Sonata      Sedan              Yes
# 19234  26108   836      HYUNDAI    Tucson       Jeep              Yes
# 19235   5331  1288    CHEVROLET   Captiva       Jeep              Yes
# 19236    470   753      HYUNDAI    Sonata      Sedan              Yes
#
#       Fuel type  Engine volume  Mileage  Cylinders Gear box type Drive wheels  \
# ...

# %% [markdown]
# # transformer data

# %%
dobject=data.select_dtypes(include='object')
dnumeric = data.select_dtypes(exclude='object')

# %%
from sklearn.preprocessing import LabelEncoder
la=LabelEncoder()

# %%
for i in range(0,dobject.shape[1]):
    dobject.iloc[:,i]=la.fit_transform(dobject.iloc[:,i])

# %%
data=pd.concat([dobject,dnumeric],axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11946 entries, 2 to 19236
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      11946 non-null  int32
#  1   Model             11946 non-null  int32
#  2   Category          11946 non-null  int32
#  3   Leather interior  11946 non-null  int32
#  4   Fuel type         11946 non-null  int32
#  5   Mileage           11946 non-null  int32
#  6   Gear box type     11946 non-null  int32
#  7   Drive wheels      11946 non-null  int32
#  8   Price             11946 non-null  int64
#  9   Levy              11946 non-null  int32
#  10  Engine volume     11946 non-null  float64
#  11  Cylinders         11946 non-null  float64
#  12  Doors             11946 non-null  int64
#  13  Airbags           11946 non-null  int64
#  14  Age               11946 non-null  int64
# dtypes: float64(2), int32(9), int64(4)
# memory usage: 1.0 MB

# %% [markdown]
# # Model

# %%
x=data.drop('Price',axis=1)
y=data['Price']

# %%
# diviser data 
from sklearn.model_selection import train_test_split

# %%
data.describe()
# Out:
#        Manufacturer         Model      Category  Leather interior  \
# count  11946.000000  11946.000000  11946.000000      11946.000000
# mean      24.442156    415.359786      5.933785          0.729951
# std       13.253729    211.774805      2.279738          0.444003
# min        0.000000      0.000000      0.000000          0.000000
# 25%       16.000000    241.000000      4.000000          0.000000
# 50%       16.000000    399.000000      8.000000          1.000000
# 75%       42.000000    612.000000      8.000000          1.000000
# max       46.000000    796.000000      9.000000          1.000000
#
#           Fuel type       Mileage  Gear box type  Drive wheels         Price  \
# count  11946.000000  11946.000000   11946.000000  11946.000000  11946.000000
# mean       2.853256   2660.576427       0.455383      0.955048  15233.895195
# std        1.247107   1735.359415       0.906269      0.345377  11320.463251
# ...

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2)

# %%
pip install xgboost
# Out:
# ...
#                                               0.0/99.7 MB ? eta -:--:--
#                                               0.1/99.7 MB 1.7 MB/s eta 0:01:01
#                                               0.4/99.7 MB 4.6 MB/s eta 0:00:22
#                                               0.7/99.7 MB 5.7 MB/s eta 0:00:18
#                                               1.1/99.7 MB 6.6 MB/s eta 0:00:15
#                                               1.5/99.7 MB 6.7 MB/s eta 0:00:15
#                                               1.8/99.7 MB 6.6 MB/s eta 0:00:15
#                                               2.2/99.7 MB 6.9 MB/s eta 0:00:15
#                                               2.5/99.7 MB 6.8 MB/s eta 0:00:15
#      -                                        2.8/99.7 MB 7.0 MB/s eta 0:00:14
#      -                                        3.2/99.7 MB 7.1 MB/s eta 0:00:14
#      -                                        3.3/99.7 MB 6.7 MB/s eta 0:00:15
# ...

# %%
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor  # Add this line
from sklearn.neural_network import MLPRegressor


from sklearn.metrics import r2_score, mean_squared_error

# %%
models = [
    LinearRegression(),
    DecisionTreeRegressor(random_state=42),
    RandomForestRegressor(random_state=42),
    XGBRegressor()
    
]

# Boucle à travers les modèles, les entraîne et les évalue
for model in models:
    model_name = type(model).__name__
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    
    mse = mean_squared_error(y_test, y_pred)
    r_squared = model.score(x_test, y_test)
    score= model.score(x_test,y_test)
    r2 =r2_score(y_test, y_pred)
    
    print(f"Modèle : {model_name}")

    print(f"score de ce model est  : {score}")
    
    
    print("="*50)
# Out:
# Modèle : LinearRegression
# score de ce model est  : 0.21045946601168364
# ...
# Modèle : DecisionTreeRegressor
# score de ce model est  : 0.6321719209148903
# ...
# Modèle : RandomForestRegressor
# score de ce model est  : 0.7889673800157864
# ...
# Modèle : XGBRegressor
# score de ce model est  : 0.7896670267064806
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Supposons que x_train, y_train, x_test, y_test soient définis

models = [
    LinearRegression(),
    DecisionTreeRegressor(random_state=42),
    RandomForestRegressor(random_state=42),
    XGBRegressor()
]

# Boucle à travers les modèles, les entraîne et les évalue
for model in models:
    model_name = type(model).__name__
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    
    mse = mean_squared_error(y_test, y_pred)
    r_squared = model.score(x_test, y_test)
    score = r2_score(y_test, y_pred)
    
    print(f"Modèle : {model_name}")
    print(f"MSE : {mse}") 
    print("=" * 50)
# Out:
# Modèle : LinearRegression
# MSE : 100140382.59399068
# R-squared : 0.21045946601168364
# 10 premières prédictions sur l'ensemble de test : [17997.38057882  8878.64376611 16411.55473473 16043.9287343
#  18591.04996963 14110.64946658  6304.88361422 23772.92557645
#  22571.31000511  9743.29574988]
# ...
# Modèle : DecisionTreeRegressor
# MSE : 46653012.71149256
# R-squared : 0.6321719209148903
# 10 premières prédictions sur l'ensemble de test : [2.6591e+04 1.8531e+04 3.1000e+01 2.2000e+02 1.5681e+04 1.4740e+04
#  1.0000e+00 4.0057e+04 3.0282e+04 9.0950e+03]
# ...
# Modèle : RandomForestRegressor
# MSE : 26766057.466714084
# R-squared : 0.7889673800157864
# 10 premières prédictions sur l'ensemble de test : [27192.96   18628.06      55.845   3603.06   15761.9405 13046.92
#   5967.81   38604.035  30332.21    8376.36  ]
# ...
# Modèle : XGBRegressor
# MSE : 26677318.656899188
# R-squared : 0.7896670267064806
# ...

# %%
data[ue()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 data.unique()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'
